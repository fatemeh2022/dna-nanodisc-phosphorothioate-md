# %%
from itertools import zip_longest

with open("bak_O1P_correct.rtp") as f1, open("bak_O1P.rtp") as f2:
    for i, (a, b) in enumerate(zip_longest(f1, f2), start=1):
        if a != b:
            print(f"Line {i}:\n  file1: {a}\n  file2: {b}")
