# %%
import re

# Read the file content
with open("DT_.rtp", "r") as file:
    text = file.read()

# Replacement dictionary
replacements = {
    "C1":"C5'",
    "O2":";RO5'",
    "C3":"C4'",
    "O4":"O4'",
    "C5":"C3'",
    "O6":";RO3'",
    "C7":"C2'", 
    "C8":"C1'",
    "N9":"N1",
    "C10":"C2",
    "O11":"O2",
    "N12":"N3",
    "C13":"C4",
    "O14":"O4",
    "C15":"C5",
    "C16":"C5M",
    "C17":"C6",
    "H18":"H3",
    "H19":"H6",
    "H20":"H1'",
    "H21":"H2'1",
    "H22":"H3'",
    "H23":"H4'",
    "H24":"H5'1",
    "H25":"H5M3",
    "H26":"H5M1",
    "H27":"H5M2",
    "H28":"H2'2",
    "H29":"H5'2",
    "H30":";RHO5'",
    "H31":";RHO3'"
}

# Replace with a regex that matches atom names surrounded by spaces, tabs, or line breaks
for old_word, new_word in replacements.items():
    pattern = rf'(?<=\s){old_word}(?=\s|$)'  # match only if surrounded by spaces or end of line
    text = re.sub(pattern, new_word, text)

# Save the modified file
with open("DT_rename.rtp", "w") as file:
    file.write(text)

print("DA changes atom names in atom and bonds sections.")
# Out:
# DA changes atom names in atom and bonds sections.

# %%
import re

# Read the file content
with open("O1P.rtp", "r") as file:
    text = file.read()

# Replacement dictionary
replacements = {
    "P6":'P',
    "O10":"O5'",
    "O7":"O1P",
    "O2":"O3'",
    "C9":";RC5'",
    "C1":";RC3'",
    "O8":"O2P",
    "C11":"C11L",
    "C12":"C12L",
    "C13":"C13L",
    "C14":"C14L",
    "C15":"C15L",
    "C16":"C16L",
    "C17":"C17L",
    "H18":"H14L",
    "H19":"H15L",
    "H20":"H16L",
    "H21":"H17L",
    "H22":"H18L",
    "H23":"H19L",
    "H24":"H20L",
    "H25":"H21L",
    "H26":"H22L",
    "H27":"H23L",
    "H28":"H24L",
    "H29":"H25L",
    "H30":"H26L",
    "H31":"H27L",
    "H35":"H28L",
    "H32":";RH29L",
    "H33":";RH30L",
    "H34":";RH31L",
    "H3":";RH32L",
    "H4":";RH33L",
    "H5":";RH34L"
}
# Replace with a regex that matches atom names surrounded by spaces, tabs, or line breaks
for old_word, new_word in replacements.items():
    pattern = rf'(?<=\s){old_word}(?=\s|$)'  # match only if surrounded by spaces or end of line
    text = re.sub(pattern, new_word, text)

# Save the modified file
with open("O1P_rename.rtp", "w") as file:
    file.write(text)

print("DA changes atom names in atom and bonds sections.")
# Out:
# DA changes atom names in atom and bonds sections.

# %%
# Read the first modified file
with open("DT_rename.rtp", "r") as f1:
    dti_text = f1.read()

# Read the second modified file
with open("O1P_rename.rtp", "r") as f2:
    linker_text = f2.read()

# Combine them with a separator (optional)
merged_text = dti_text.strip() + "\n\n; ====== LINKER SECTION BELOW ======\n\n" + linker_text.strip()

# Save the merged file
with open("merged_DT_O1P_new.rtp", "w") as fout:
    fout.write(merged_text)

print("✅ Done! Created merged_output.rtp with both modified contents.")
# Out:
# ✅ Done! Created merged_output.rtp with both modified contents.
